# %% [markdown]
# # Training a VAE to the MNIST dataset
# We want to create a VAE which represents the images in the MNIST dataset. This serves as a practice for VAEs in theory and their relative tensorflow implementation.
# At the end, we will present some generated samples for comparison.

# %%
import mnist, scipy
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tnrange

# %% [markdown]
# Now we need to import the train set of the MNIST dataset. A this point, we do not care for the testset. The testset could be used, for example, to test a classifier based on the hidden vector generated by the VAE. We also do not care about the labels now, since this is an unsupervised approach.

# %%
images = mnist.train_images()
images = images / 256

# %%
plt.imshow(images[42])
plt.show()

# %% [markdown]
# ## Defining the AE
# Now we want to define the structure of the AE using TF. The AE has 2 main components:
# - Encoder: convolutional layers
# - Decoder: deconvolutional layers
# The specific distribution we want in a VAE is enforced by the loss we define. We want the encoder to output mean and standard deviations of a fixed number of distributions (which we want to be normal gaussians)

# %%
BATCH_SIZE = 64
LATENT_SIZE = 10
LEARNING_RATE = 0.0005

tf.reset_default_graph()

# Input image
X = tf.placeholder(dtype=tf.float32, shape=(None, 28, 28))
# Reshape for convolution
X4d = tf.reshape(X, shape=(-1, 28, 28, 1))
# Dropout keep proba
keep_prob = tf.placeholder(dtype=tf.float32, shape=(), name='keep_prob')

# ENCODER GRAPH
with tf.variable_scope("encoder", reuse=None):
    conv1 = tf.layers.conv2d(X4d, filters=64, kernel_size=4, strides=2, padding='same', activation=tf.nn.relu)
    drop1 = tf.nn.dropout(conv1, keep_prob)
    conv2 = tf.layers.conv2d(drop1, filters=64, kernel_size=4, strides=2, padding='same', activation=tf.nn.relu)
    drop2 = tf.nn.dropout(conv2, keep_prob)
    conv3 = tf.layers.conv2d(drop2, filters=64, kernel_size=4, strides=1, padding='same', activation=tf.nn.relu)
    drop3 = tf.nn.dropout(conv3, keep_prob)
    flat = tf.layers.flatten(drop3)
    latent_means = tf.layers.dense(flat, units=LATENT_SIZE)
    latent_std = tf.layers.dense(flat, units=LATENT_SIZE)
    latent_noise = tf.random_normal(shape=(BATCH_SIZE, LATENT_SIZE))
    latent_vector = latent_means + tf.multiply(latent_std, latent_noise)

# DECODER GRAPH
with tf.variable_scope("decoder", reuse=None):
    deflat = tf.layers.dense(latent_vector, units=flat.shape[1])
    deflat4d = tf.reshape(deflat, shape=(-1, drop3.shape[1], drop3.shape[2], drop3.shape[3]))
    deconv1 = tf.layers.conv2d_transpose(deflat4d, filters=64, kernel_size=4, strides=1, padding='same', activation=tf.nn.relu)
    dedrop1 = tf.nn.dropout(deconv1, keep_prob)
    deconv2 = tf.layers.conv2d_transpose(dedrop1, filters=64, kernel_size=4, strides=2, padding='same', activation=tf.nn.relu)
    dedrop2 = tf.nn.dropout(deconv2, keep_prob)
    deconv3 = tf.layers.conv2d_transpose(dedrop2, filters=1, kernel_size=4, strides=2, padding='same', activation=tf.nn.relu)
    dedrop3 = tf.nn.dropout(deconv3, keep_prob)
    rebuild = tf.reshape(dedrop3, shape=(-1, 28, 28))
    
# Loss
reconstruction_loss = tf.reduce_sum(tf.squared_difference(rebuild, X))
reg_loss = tf.reduce_sum(-tf.log(tf.abs(latent_std)) + 0.5 * (tf.square(latent_std) + tf.square(latent_means) - 1))
complete_loss = reconstruction_loss + reg_loss

# Optimizer
optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(complete_loss)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
# Training
N_EPOCHS = 200
for epoch in tnrange(N_EPOCHS):
    losses = []
    for bindex in range(0, 16384, BATCH_SIZE):
        batch = images[bindex:bindex+BATCH_SIZE]
        _loss, _ = sess.run([complete_loss, optimizer], feed_dict = {X: batch, keep_prob:0.8})
        losses.append(_loss)
    print("Epoch", epoch, "- Mean Loss:", np.mean(losses))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Epoch 0 - Mean Loss: 4017.6729
# Epoch 1 - Mean Loss: 3410.108
# Epoch 2 - Mean Loss: 3176.6355
# Epoch 3 - Mean Loss: 3097.524
# Epoch 4 - Mean Loss: 3038.7773
# Epoch 5 - Mean Loss: 3002.3665
# Epoch 6 - Mean Loss: 2975.906
# Epoch 7 - Mean Loss: 2953.0562
# Epoch 8 - Mean Loss: 2942.2664
# Epoch 9 - Mean Loss: 2925.2866
# Epoch 10 - Mean Loss: 2916.168
# Epoch 11 - Mean Loss: 2899.7114
# Epoch 12 - Mean Loss: 2895.1865
# Epoch 13 - Mean Loss: 2887.9731
# Epoch 14 - Mean Loss: 2882.2817
# Epoch 15 - Mean Loss: 2875.535
# Epoch 16 - Mean Loss: 2869.2195
# Epoch 17 - Mean Loss: 2865.0186
# Epoch 18 - Mean Loss: 2863.524
# Epoch 19 - Mean Loss: 2854.935
# Epoch 20 - Mean Loss: 2857.8525
# Epoch 21 - Mean Loss: 2851.08
# Epoch 22 - Mean Loss: 2847.4666
# Epoch 23 - Mean Loss: 2842.0623
# Epoch 24 - Mean Loss: 2836.3596
# Epoch 25 - Mean Loss: 2830.0918
# Epoch 26 - Mean Loss: 2835.3818
# Epoch 27 - Mean Loss: 2833.2097
# Epoch 28 - Mean Loss: 2833.1665
# Epoch 29 - Mean Loss: 2825.708
# Epoch 30 - Mean Loss: 2822.983
# Epoch 31 - Mean Loss: 2823.1714
# Epoch 32 - Mean Loss: 2821.5298
# Epoch 33 - Mean Loss: 2821.8838
# Epoch 34 - Mean Loss: 2816.5928
# Epoch 35 - Mean Loss: 2819.9436
# Epoch 36 - Mean Loss: 2814.809
# Epoch 37 - Mean Loss: 2814.0237
# Epoch 38 - Mean Loss: 2812.9954
# Epoch 39 - Mean Loss: 2811.15
# Epoch 40 - Mean Loss: 2804.5667
# Epoch 41 - Mean Loss: 2809.3262
# Epoch 42 - Mean Loss: 2806.0261
# Epoch 43 - Mean Loss: 2805.151
# Epoch 44 - Mean Loss: 2803.2288
# Epoch 45 - Mean Loss: 2803.2874
# Epoch 46 - Mean Loss: 2803.9883
# Epoch 47 - Mean Loss: 2796.377
# Epoch 48 - Mean Loss: 2801.0647
# Epoch 49 - Mean Loss: 2801.896
# Epoch 50 - Mean Loss: 2801.5056
# Epoch 51 - Mean Loss: 2799.2744
# Epoch 52 - Mean Loss: 2796.7776
# Epoch 53 - Mean Loss: 2792.5703
# Epoch 54 - Mean Loss: 2796.1833
# Epoch 55 - Mean Loss: 2793.8374
# Epoch 56 - Mean Loss: 2789.2468
# Epoch 57 - Mean Loss: 2793.6157
# Epoch 58 - Mean Loss: 2790.7935
# Epoch 59 - Mean Loss: 2787.165
# Epoch 60 - Mean Loss: 2794.6768
# Epoch 61 - Mean Loss: 2789.7588
# Epoch 62 - Mean Loss: 2790.6455
# Epoch 63 - Mean Loss: 2785.183
# Epoch 64 - Mean Loss: 2785.348
# Epoch 65 - Mean Loss: 2786.7234
# Epoch 66 - Mean Loss: 2783.9097
# Epoch 67 - Mean Loss: 2787.111
# Epoch 68 - Mean Loss: 2785.154
# Epoch 69 - Mean Loss: 2781.6538
# Epoch 70 - Mean Loss: 2784.87
# Epoch 71 - Mean Loss: 2778.5845
# Epoch 72 - Mean Loss: 2782.5884
# Epoch 73 - Mean Loss: 2776.8357
# Epoch 74 - Mean Loss: 2784.1343
# Epoch 75 - Mean Loss: 2779.7673
# Epoch 76 - Mean Loss: 2781.1746
# Epoch 77 - Mean Loss: 2779.2603
# Epoch 78 - Mean Loss: 2777.1582
# Epoch 79 - Mean Loss: 2780.6118
# Epoch 80 - Mean Loss: 2774.0215
# Epoch 81 - Mean Loss: 2773.62
# Epoch 82 - Mean Loss: 2778.412
# Epoch 83 - Mean Loss: 2776.4888
# Epoch 84 - Mean Loss: 2778.1738
# Epoch 85 - Mean Loss: 2771.7305
# Epoch 86 - Mean Loss: 2770.561
# Epoch 87 - Mean Loss: 2774.7673
# Epoch 88 - Mean Loss: 2772.4827
# Epoch 89 - Mean Loss: 2778.7412
# Epoch 90 - Mean Loss: 2770.0225
# Epoch 91 - Mean Loss: 2768.856
# Epoch 92 - Mean Loss: 2771.0317
# Epoch 93 - Mean Loss: 2771.4421
# Epoch 94 - Mean Loss: 2769.6458
# Epoch 95 - Mean Loss: 2771.3394
# Epoch 96 - Mean Loss: 2771.4775
# Epoch 97 - Mean Loss: 2767.3848
# Epoch 98 - Mean Loss: 2766.0706
# Epoch 99 - Mean Loss: 2763.081
# Epoch 100 - Mean Loss: 2768.9817
# Epoch 101 - Mean Loss: 2773.226
# Epoch 102 - Mean Loss: 2767.2246
# Epoch 103 - Mean Loss: 2765.2437
# Epoch 104 - Mean Loss: 2764.5894
# Epoch 105 - Mean Loss: 2768.2744
# Epoch 106 - Mean Loss: 2771.229
# Epoch 107 - Mean Loss: 2767.2349
# Epoch 108 - Mean Loss: 2769.7188
# Epoch 109 - Mean Loss: 2768.6482
# Epoch 110 - Mean Loss: 2765.1836
# Epoch 111 - Mean Loss: 2762.252
# Epoch 112 - Mean Loss: 2770.6582
# Epoch 113 - Mean Loss: 2758.9214
# Epoch 114 - Mean Loss: 2768.2363
# Epoch 115 - Mean Loss: 2761.5337
# Epoch 116 - Mean Loss: 2764.5159
# Epoch 117 - Mean Loss: 2767.5845
# Epoch 118 - Mean Loss: 2764.0146
# Epoch 119 - Mean Loss: 2760.7166
# Epoch 120 - Mean Loss: 2762.2903
# Epoch 121 - Mean Loss: 2758.6
# Epoch 122 - Mean Loss: 2763.6633
# Epoch 123 - Mean Loss: 2762.5132
# Epoch 124 - Mean Loss: 2767.8716
# Epoch 125 - Mean Loss: 2759.783
# Epoch 126 - Mean Loss: 2760.7188
# Epoch 127 - Mean Loss: 2758.0547
# Epoch 128 - Mean Loss: 2759.7168
# Epoch 129 - Mean Loss: 2759.1248
# Epoch 130 - Mean Loss: 2760.7012
# Epoch 131 - Mean Loss: 2761.6807
# Epoch 132 - Mean Loss: 2758.8784
# Epoch 133 - Mean Loss: 2760.4265
# Epoch 134 - Mean Loss: 2757.7534
# Epoch 135 - Mean Loss: 2760.4546
# Epoch 136 - Mean Loss: 2759.443
# Epoch 137 - Mean Loss: 2755.4302
# Epoch 138 - Mean Loss: 2756.2283
# Epoch 139 - Mean Loss: 2758.7312
# Epoch 140 - Mean Loss: 2758.1768
# Epoch 141 - Mean Loss: 2758.0396
# Epoch 142 - Mean Loss: 2757.261
# Epoch 143 - Mean Loss: 2758.151
# Epoch 144 - Mean Loss: 2756.1895
# Epoch 145 - Mean Loss: 2755.2734
# Epoch 146 - Mean Loss: 2758.5784
# Epoch 147 - Mean Loss: 2754.2815
# Epoch 148 - Mean Loss: 2759.9412
# Epoch 149 - Mean Loss: 2753.6758
# Epoch 150 - Mean Loss: 2761.9644
# Epoch 151 - Mean Loss: 2752.85
# Epoch 152 - Mean Loss: 2758.7896
# Epoch 153 - Mean Loss: 2757.6191
# Epoch 154 - Mean Loss: 2755.094
# Epoch 155 - Mean Loss: 2750.084
# Epoch 156 - Mean Loss: 2751.8232
# Epoch 157 - Mean Loss: 2756.5957
# Epoch 158 - Mean Loss: 2755.5825
# Epoch 159 - Mean Loss: 2758.6257
# Epoch 160 - Mean Loss: 2755.3643
# Epoch 161 - Mean Loss: 2750.9536
# Epoch 162 - Mean Loss: 2755.6084
# Epoch 163 - Mean Loss: 2753.0398
# Epoch 164 - Mean Loss: 2751.921
# Epoch 165 - Mean Loss: 2750.8184
# Epoch 166 - Mean Loss: 2755.9321
# Epoch 167 - Mean Loss: 2749.4521
# Epoch 168 - Mean Loss: 2755.876
# Epoch 169 - Mean Loss: 2751.713
# Epoch 170 - Mean Loss: 2749.9536
# Epoch 171 - Mean Loss: 2752.9736
# Epoch 172 - Mean Loss: 2751.8848
# Epoch 173 - Mean Loss: 2752.878
# Epoch 174 - Mean Loss: 2752.8345
# Epoch 175 - Mean Loss: 2750.8928
# Epoch 176 - Mean Loss: 2750.9917
# Epoch 177 - Mean Loss: 2752.0625
# Epoch 178 - Mean Loss: 2751.3105
# Epoch 179 - Mean Loss: 2745.8748
# Epoch 180 - Mean Loss: 2747.877
# Epoch 181 - Mean Loss: 2745.4473
# Epoch 182 - Mean Loss: 2754.4922
# Epoch 183 - Mean Loss: 2752.1772
# Epoch 184 - Mean Loss: 2747.291
# Epoch 185 - Mean Loss: 2749.9038
# Epoch 186 - Mean Loss: 2749.2349
# Epoch 187 - Mean Loss: 2746.2505
# Epoch 188 - Mean Loss: 2749.8474
# Epoch 189 - Mean Loss: 2749.19
# Epoch 190 - Mean Loss: 2748.2397
# Epoch 191 - Mean Loss: 2747.2876
# Epoch 192 - Mean Loss: 2749.2827
# Epoch 193 - Mean Loss: 2748.065
# Epoch 194 - Mean Loss: 2748.857
# Epoch 195 - Mean Loss: 2750.876
# Epoch 196 - Mean Loss: 2749.3623
# Epoch 197 - Mean Loss: 2747.518
# Epoch 198 - Mean Loss: 2751.2227
# Epoch 199 - Mean Loss: 2749.5847

# %%
R, C = 8, 8
z = np.random.standard_normal((R*C, LATENT_SIZE))
reco = sess.run(rebuild, feed_dict = {latent_vector: z, keep_prob:1.0})
f, ax = plt.subplots(R, C, figsize=(16,16))
for r in range(R):
    for c in range(C):
        ax[r,c].imshow(reco[r*8 + c])
plt.show()

# %% [markdown]
# Generate samples in the 2d space [-1, 1] of the latent vector

# %%
R, C = 8, 8
latent_samples = []
for r in range(1,R+1):
    for c in range(1,C+1):
        latent_samples.append([(2/r)-1,(2/c)-1] + [0] * 8)
latent_samples = np.array(latent_samples)
reco = sess.run(rebuild, feed_dict = {latent_vector: latent_samples, keep_prob:1.0})
f, ax = plt.subplots(R, C, figsize=(16,16))
for r in range(R):
    for c in range(C):
        ax[r,c].imshow(reco[r*8 + c])
plt.show()
# Out:
# (64, 10)
